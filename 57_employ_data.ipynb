# %% [markdown]
# <a href="https://colab.research.google.com/github/gitanjalisalunke/earthquake-prediction/blob/main/57_employ_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# data mining project_gitanjali salunke_57_employ data_data science branch.

# %%
from google.colab import drive
drive.mount('/content/drive')
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/train gitanjali.csv')

# %%
df
# Out:
#       age         workclass  fnlwgt     education  educational-num  \
# 0      67           Private  366425     Doctorate               16
# 1      17           Private  244602          12th                8
# 2      31           Private  174201     Bachelors               13
# 3      58         State-gov  110199       7th-8th                4
# 4      25         State-gov  149248  Some-college               10
# ...   ...               ...     ...           ...              ...
# 1145   49           Private  247294       HS-grad                9
# 1146   39           Private  148485  Some-college               10
# 1147   20               NaN  308924  Some-college               10
# 1148   55  Self-emp-not-inc   99551     Bachelors               13
# 1149   56           Private  247119       7th-8th                4
#
#           marital-status         occupation   relationship   race  gender  \
# 0               Divorced    Exec-managerial  Not-in-family  White    Male
# ...

# %%
df.set_index('age',inplace=True)

# %%
df
# Out:
#             workclass  fnlwgt     education  educational-num  \
# age
# 67            Private  366425     Doctorate               16
# 17            Private  244602          12th                8
# 31            Private  174201     Bachelors               13
# 58          State-gov  110199       7th-8th                4
# 25          State-gov  149248  Some-college               10
# ..                ...     ...           ...              ...
# 49            Private  247294       HS-grad                9
# 39            Private  148485  Some-college               10
# 20                NaN  308924  Some-college               10
# 55   Self-emp-not-inc   99551     Bachelors               13
# 56            Private  247119       7th-8th                4
#
#          marital-status         occupation   relationship   race  gender  \
# age
# 67             Divorced    Exec-managerial  Not-in-family  White    Male
# ...

# %%
df.isna()
# Out:
#      workclass  fnlwgt  education  educational-num  marital-status  \
# age
# 67       False   False      False            False           False
# 17       False   False      False            False           False
# 31       False   False      False            False           False
# 58       False   False      False            False           False
# 25       False   False      False            False           False
# ..         ...     ...        ...              ...             ...
# 49       False   False      False            False           False
# 39       False   False      False            False           False
# 20        True   False      False            False           False
# 55       False   False      False            False           False
# 56       False   False      False            False           False
#
#      occupation  relationship   race  gender  capital-gain  capital-loss  \
# age
# 67        False         False  False   False         False         False
# ...

# %%
df.head()
# Out:
#      workclass  fnlwgt     education  educational-num      marital-status  \
# age
# 67     Private  366425     Doctorate               16            Divorced
# 17     Private  244602          12th                8       Never-married
# 31     Private  174201     Bachelors               13  Married-civ-spouse
# 58   State-gov  110199       7th-8th                4  Married-civ-spouse
# 25   State-gov  149248  Some-college               10       Never-married
#
#            occupation   relationship   race gender  capital-gain  \
# age
# 67    Exec-managerial  Not-in-family  White   Male         99999
# 17                NaN      Own-child  White   Male             0
# 31    Exec-managerial        Husband  White   Male             0
# 58   Transport-moving        Husband  White   Male             0
# 25      Other-service  Not-in-family  Black   Male             0
#
#      capital-loss  hours-per-week native-country income_>50K
# age
# ...

# %%
df.tail()
# Out:
#             workclass  fnlwgt     education  educational-num  \
# age
# 49            Private  247294       HS-grad                9
# 39            Private  148485  Some-college               10
# 20                NaN  308924  Some-college               10
# 55   Self-emp-not-inc   99551     Bachelors               13
# 56            Private  247119       7th-8th                4
#
#          marital-status         occupation relationship   race  gender  \
# age
# 49   Married-civ-spouse       Craft-repair      Husband  White    Male
# 39   Married-civ-spouse       Craft-repair      Husband  White    Male
# 20        Never-married                NaN    Own-child  White    Male
# 55              Widowed              Sales    Unmarried  White  Female
# 56              Widowed  Machine-op-inspct    Unmarried  Other  Female
#
#      capital-gain  capital-loss  hours-per-week      native-country  \
# age
# 49              0             0              45       United-States
# ...

# %%
df.isna().sum()
# Out:
# workclass          71
# fnlwgt              0
# education           9
# educational-num     0
# marital-status      1
# occupation         76
# relationship        0
# race                0
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country     17
# income_>50K         0
# dtype: int64

# %%
df.isna().sum().sum()
# Out:
# 174

# %%
new_df =df.fillna({
        'workclass': 'private',
        'education' : 'graduate',
        'marital-status': 'Never-married',
       'occupation':'service',
       'native-country':'japan'
    })

# %%
new_df
# Out:
#             workclass  fnlwgt     education  educational-num  \
# age
# 67            Private  366425     Doctorate               16
# 17            Private  244602          12th                8
# 31            Private  174201     Bachelors               13
# 58          State-gov  110199       7th-8th                4
# 25          State-gov  149248  Some-college               10
# ..                ...     ...           ...              ...
# 49            Private  247294       HS-grad                9
# 39            Private  148485  Some-college               10
# 20            private  308924  Some-college               10
# 55   Self-emp-not-inc   99551     Bachelors               13
# 56            Private  247119       7th-8th                4
#
#          marital-status         occupation   relationship   race  gender  \
# age
# 67             Divorced    Exec-managerial  Not-in-family  White    Male
# ...

# %%
educationalnum_mean=new_df['educational-num'].mean()
educationalnum_mean
# Out:
# 10.037391304347826

# %%
new_df['educational-num'].fillna(value=educationalnum_mean, inplace=True)

# %%
hoursperweek_median=new_df['hours-per-week'].median()
hoursperweek_median
# Out:
# 40.0

# %%
new_df['hours-per-week'].fillna(value=hoursperweek_median, inplace=True)

# %%
new_df
# Out:
#             workclass  fnlwgt     education  educational-num  \
# age
# 67            Private  366425     Doctorate               16
# 17            Private  244602          12th                8
# 31            Private  174201     Bachelors               13
# 58          State-gov  110199       7th-8th                4
# 25          State-gov  149248  Some-college               10
# ..                ...     ...           ...              ...
# 49            Private  247294       HS-grad                9
# 39            Private  148485  Some-college               10
# 20            private  308924  Some-college               10
# 55   Self-emp-not-inc   99551     Bachelors               13
# 56            Private  247119       7th-8th                4
#
#          marital-status         occupation   relationship   race  gender  \
# age
# 67             Divorced    Exec-managerial  Not-in-family  White    Male
# ...

# %%
workclass_mode =new_df['workclass'].mode()
workclass_mode
# Out:
# 0    Private
# Name: workclass, dtype: object

# %%
new_df['workclass'].fillna(value=workclass_mode, inplace=True)

# %%
df.isna().sum()
# Out:
# workclass          71
# fnlwgt              0
# education           9
# educational-num     0
# marital-status      1
# occupation         76
# relationship        0
# race                0
# gender              0
# capital-gain        0
# capital-loss        0
# hours-per-week      0
# native-country     17
# income_>50K         0
# dtype: int64

# %%
new_df.isna().sum()
# Out:
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income_>50K        0
# dtype: int64

# %%
new_df.head()
# Out:
#      workclass  fnlwgt     education  educational-num      marital-status  \
# age
# 67     Private  366425     Doctorate               16            Divorced
# 17     Private  244602          12th                8       Never-married
# 31     Private  174201     Bachelors               13  Married-civ-spouse
# 58   State-gov  110199       7th-8th                4  Married-civ-spouse
# 25   State-gov  149248  Some-college               10       Never-married
#
#            occupation   relationship   race gender  capital-gain  \
# age
# 67    Exec-managerial  Not-in-family  White   Male         99999
# 17            service      Own-child  White   Male             0
# 31    Exec-managerial        Husband  White   Male             0
# 58   Transport-moving        Husband  White   Male             0
# 25      Other-service  Not-in-family  Black   Male             0
#
#      capital-loss  hours-per-week native-country income_>50K
# age
# ...

# %%
import numpy as np
new_df['gender']=np.where(new_df['gender']=="Male",1,0)
new_df.head()
# Out:
#      workclass  fnlwgt     education  educational-num      marital-status  \
# age
# 67     Private  366425     Doctorate               16            Divorced
# 17     Private  244602          12th                8       Never-married
# 31     Private  174201     Bachelors               13  Married-civ-spouse
# 58   State-gov  110199       7th-8th                4  Married-civ-spouse
# 25   State-gov  149248  Some-college               10       Never-married
#
#            occupation   relationship   race  gender  capital-gain  \
# age
# 67    Exec-managerial  Not-in-family  White       1         99999
# 17            service      Own-child  White       1             0
# 31    Exec-managerial        Husband  White       1             0
# 58   Transport-moving        Husband  White       1             0
# 25      Other-service  Not-in-family  Black       1             0
#
#      capital-loss  hours-per-week native-country income_>50K
# age
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lab = LabelEncoder()
new_df['workclass'] = lab.fit_transform(new_df['workclass'])
new_df['education'] = lab.fit_transform(new_df['education'])
new_df['marital-status'] = lab.fit_transform(new_df['marital-status'])
new_df['occupation'] = lab.fit_transform(new_df['occupation'])
new_df['relationship'] = lab.fit_transform(new_df['relationship'])
new_df['race'] = lab.fit_transform(new_df['race'])
new_df['native-country'] = lab.fit_transform(new_df['native-country'])
new_df.columns
# Out:
# Index(['workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'capital-gain',
#        'capital-loss', 'hours-per-week', 'native-country', 'income_>50K'],
#       dtype='object')

# %% [markdown]
# lable encodder......conver all chategerical value into numerical value applicable only for string

# %%
X = new_df.drop("income_>50K",axis=1)   #Feature Matrix
y = new_df["income_>50K"]

# %%
# separate dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0)

X_train.shape, X_test.shape
# Out:
# ((805, 13), (345, 13))

# %%
X_train.corr()
# Out:
#                  workclass    fnlwgt  education  educational-num  \
# workclass         1.000000 -0.035245   0.062062         0.025547
# fnlwgt           -0.035245  1.000000  -0.020167        -0.019820
# education         0.062062 -0.020167   1.000000         0.361045
# educational-num   0.025547 -0.019820   0.361045         1.000000
# marital-status    0.048269  0.021101  -0.032644        -0.083576
# occupation        0.297893 -0.038820   0.002259         0.088330
# relationship      0.042471 -0.044165  -0.076784        -0.176913
# race             -0.125239 -0.072561   0.042313         0.084880
# gender            0.025514  0.040643   0.007879         0.057633
# capital-gain     -0.022947  0.051921   0.036756         0.144240
# capital-loss     -0.018947  0.046646  -0.031593         0.045650
# hours-per-week   -0.057569 -0.004424   0.115646         0.133815
# native-country   -0.076127 -0.048354   0.043707         0.097762
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = X_train.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.CMRmap_r)
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import LabelEncoder
import matplotlib.pyplot as plt


X = new_df.drop('income_>50K', axis=1)
Y = new_df['income_>50K']

# Encode the target variable
le = LabelEncoder()
Y = le.fit_transform(Y)

# Split the data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Create the decision tree classifier
clf = DecisionTreeClassifier()

# Train the classifier
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Create the decision tree classifier
clf = DecisionTreeClassifier()

# Train the classifier
clf.fit(X_train, Y_train)

# Visualize the decision tree
plt.figure(figsize=(80,40))
plot_tree(clf, feature_names=X.columns, class_names=['yes', 'no'], filled=True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Create the decision tree classifier with information gain criterion
clf = DecisionTreeClassifier(criterion='entropy')

# Train the classifier
clf.fit(X_train, Y_train)

# Visualize the decision tree
plt.figure(figsize=(20,10))
plot_tree(clf, feature_names=X.columns, class_names=['yes','no'], filled=True)
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier, plot_tree

# Create the decision tree classifier with information gain criterion
clf = DecisionTreeClassifier(max_depth=3)

# Train the classifier
clf.fit(X_train, Y_train)

# Visualize the decision tree
plt.figure(figsize=(20,10))
plot_tree(clf, feature_names=X.columns, class_names=['yes','no'], filled=True)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# Assuming df is your DataFrame containing the data
# Splitting data into features and target
X = new_df.drop(columns=['income_>50K'])
Y = new_df['income_>50K']

# Preprocessing categorical target variable
le = LabelEncoder()
Y_train = le.fit_transform(Y)

# Splitting data into training and testing sets
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Initializing Gaussian Naive Bayes classifier
nb_classifier = GaussianNB()

# Fitting the classifier to the training data
nb_classifier.fit(X_train, Y_train)

# Making predictions on the testing data
y_pred = nb_classifier.predict(X_test)

# Evaluating the classifier
accuracy = (y_pred == Y_test).mean()
print("Accuracy: \n",accuracy)
# Out:
# Accuracy:
#  0.7869565217391304

# %%
from sklearn.svm import SVC

# Initializing Support Vector Machine classifier
svm_classifier = SVC()

# Fitting the classifier to the training data
svm_classifier.fit(X_train, Y_train)

# Making predictions on the testing data
y_pred = svm_classifier.predict(X_test)

# Evaluating the classifier
accuracy = (y_pred == Y_test).mean()
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7869565217391304

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
# Initializing Support Vector Machine classifier with RBF kernel
svm_classifier = SVC(kernel='rbf') # kernel function (linear, poly, rbf, and sigmoid)

# Fitting the classifier to the training data
svm_classifier.fit(X_train, Y_train)

# Making predictions on the testing data
y_pred = svm_classifier.predict(X_test)

# Evaluating the classifier
accuracy = (y_pred == Y_test).mean()
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7869565217391304
